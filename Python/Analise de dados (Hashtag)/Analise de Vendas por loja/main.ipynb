# %%
 # Projeto - Analise de "Vendas"
# 01- percorrendo todos os arquivos da pasta (Vendas)
import os
import pandas as pd
import plotly.express as px

lista_arquivos = os.listdir(r"C:\Users\carlens.oslin\Documents\Projetos de analise de dados\Analise de Vendas por loja",)
display (lista_arquivos)
# Out:
# ['main.ipynb', 'newplot.png', 'Vendas']

# %%
tabela_total = pd.DataFrame()

# 02- Importando as bases dos dados de vendas
for arquivo in lista_arquivos:

  if "Vendas" in arquivo:
    tabela = pd.read_csv(rf"C:\Users\carlens.oslin\Documents\Projetos de analise de dados\Analise de Vendas por loja\Vendas\{arquivo}")
    tabela_total = tabela_total.append(tabela)

 #03 - Tratando / compilando as bases de dados
display(tabela_total)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11416\1622933668.py in <module>
#       5
#       6   if "Vendas" in arquivo:
# ----> 7     tabela = pd.read_csv(rf"C:\Users\carlens.oslin\Documents\Projetos de analise de dados\Analise de Vendas por loja\Vendas\{arquivo}")
#       8     tabela_total = tabela_total.append(tabela)
#       9
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# 05- Calculando o produto mais vendido em (Quantidade)
tabela_produtos = tabela_total.groupby("Produto").sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display (tabela_produtos)
# Out:
# <ipython-input-16-4d4e61fb65d7>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_produtos = tabela_total.groupby("Produto").sum()
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
# 06- Calculando o produto mais faturado (faturamento)

tabela_total["Faturamento"] = tabela_total["Quantidade Vendida"] * tabela_total["Preco Unitario"]

tabela_faturamento = tabela_total.groupby("Produto").sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
# <ipython-input-17-43928ab727aa>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_faturamento = tabela_total.groupby("Produto").sum()
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# 07- Calculando a loja que mais faturo (faturamento)
tabela_lojas = tabela_total.groupby("Loja").sum()
tabela_lojas = tabela_lojas[["Faturamento"]]
display (tabela_lojas)
# Out:
# <ipython-input-18-1aa10bd2216d>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_lojas = tabela_total.groupby("Loja").sum()
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
# 08 -(Dashboard)

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y="Faturamento")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
